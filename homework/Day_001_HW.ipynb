# %%
print("Here is the HW part1")
### 以下連結為我所選擇之資料
#[美國地區2012-2017氣象測站逐時資料](https://www.kaggle.com/selfishgene/historical-hourly-weather-data)
#[GOES-16地球同步衛星資料](https://www.kaggle.com/noaa/goes16)
print("Q1: 你選的這組資料為何重要?")
print("A: 目前氣象資訊的獲得及相關預報的獲得，無外乎源自於測站觀測資料及衛星或雷達所提供之遙測資料，將其提供給數值模式後所獲得之預報資料，因此以上資料即包含這些與人們生活息息相關之重要氣象資訊。")
print("Q2: 資料從何而來?")
print("A: 測站資料應是由美國國家大氣海洋研究署之部屬測站所測得回傳之資料、衛星資料則源自GOES-16地球同步衛星。")
print("Q3: 蒐集而來的資料型態為何?")
print("A: 測站資料為預記錄氣象場之數值資料，如溫度、濕度、氣壓等；衛星資料應包含圖像及數值兩部分資料，包含不同頻道之影像觀測等")
print("Q4: 這組資料想解決的問題如何評估?")
print("A: 在排除觀測資料會有誤差的情形下，氣象資料不外乎是提供預報用途，則有許多方法如數值方法計算趨勢或以物理方法求解預報場；若需要關切資料本身準確性，意即與其他觀測相比，則可能有正確性或相對誤差大小的問題。")

# %%
print("Here is the HW part2")
print("Q1: 核心問題為何?")
print("A: 了解什麼地方的人潮對車隊的依賴相對最高，或是在怎樣的條件下對車隊的依賴會相對提高，例如下雨可能使搭乘意願提高、舉辦某些活動可能使搭乘意願提高、某些特定路線有乘客提高之可能等。")
print("Q2: 資料從何而來?")
print("A: 在公開資料平台上尋找人潮流動通量，與相關資訊合成分析，如該日天氣、活動等等。")
print("Q3: 蒐集而來的資料型態為何?")
print("A: 數據。")
print("Q4: 你要回答的問題，其如何評估?")
print("A: 各要素做相關分析，獲得較大正相關之兩要素，並在符合該條件之時間增加車次，試驗是否符合預期效果。")

# %%
# 練習時間
#### 請寫一個函式用來計算 Mean Square Error
$ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """    
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse 

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 188.707

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.974

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 188.707
# The Mean absolute error is 10.974
